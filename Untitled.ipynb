# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
link = 'https://www.flipkart.com/search?q=i+phone+14&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY'

# %%
page = requests.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
soup = bs(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %% [markdown]
# #### Title of the product

# %%
price = soup.find_all('div', class_ = '_30jeq3 _1_WHN1')
print(price)
# Out:
# [<div class="_30jeq3 _1_WHN1">₹78,740</div>, <div class="_30jeq3 _1_WHN1">₹78,740</div>, <div class="_30jeq3 _1_WHN1">₹78,740</div>, <div class="_30jeq3 _1_WHN1">₹98,490</div>, <div class="_30jeq3 _1_WHN1">₹88,740</div>, <div class="_30jeq3 _1_WHN1">₹78,740</div>, <div class="_30jeq3 _1_WHN1">₹88,490</div>, <div class="_30jeq3 _1_WHN1">₹88,490</div>, <div class="_30jeq3 _1_WHN1">₹88,740</div>, <div class="_30jeq3 _1_WHN1">₹88,740</div>, <div class="_30jeq3 _1_WHN1">₹78,740</div>, <div class="_30jeq3 _1_WHN1">₹98,490</div>, <div class="_30jeq3 _1_WHN1">₹88,740</div>, <div class="_30jeq3 _1_WHN1">₹88,490</div>, <div class="_30jeq3 _1_WHN1">₹88,490</div>, <div class="_30jeq3 _1_WHN1">₹88,490</div>, <div class="_30jeq3 _1_WHN1">₹98,490</div>, <div class="_30jeq3 _1_WHN1">₹1,59,900</div>, <div class="_30jeq3 _1_WHN1">₹98,490</div>, <div class="_30jeq3 _1_WHN1">₹88,740</div>, <div class="_30jeq3 _1_WHN1">₹98,490</div>, <div class="_30jeq3 _1_WHN1">₹1,08,740</div>, <div class="_30jeq3 _1_WH
# ...

# %%
# product_price=[]
# for i in range(0,len(price)):
#     product_price.append(price[i].get_text())
# product_price
product_price = [i.get_text() for i in price]
product_price
# Out:
# ['₹78,740',
#  '₹78,740',
#  '₹78,740',
#  '₹98,490',
#  '₹88,740',
#  '₹78,740',
#  '₹88,490',
#  '₹88,490',
#  '₹88,740',
#  '₹88,740',
#  '₹78,740',
#  '₹98,490',
#  '₹88,740',
#  '₹88,490',
#  '₹88,490',
#  '₹88,490',
#  '₹98,490',
#  '₹1,59,900',
#  '₹98,490',
#  '₹88,740',
#  '₹98,490',
#  '₹1,08,740',
#  '₹1,39,900',
#  '₹1,69,900']

# %%
product = soup.find_all('div', class_ = '_4rR01T')
print(product)
# Out:
# [<div class="_4rR01T">APPLE iPhone 14 (Midnight, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Purple, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Blue, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 Plus (Starlight, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Blue, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Starlight, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 Plus (Starlight, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 Plus (Purple, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Starlight, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Purple, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 ((PRODUCT)RED, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 Plus (Midnight, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Midnight, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 Plus (Midnight, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 Plus (Blue, 128 GB)</div>, <div class="_4rR01T">APPLE iPhon
# ...

# %%
product_name = [i.get_text() for i in product]
product_name
# Out:
# ['APPLE iPhone 14 (Midnight, 128 GB)',
#  'APPLE iPhone 14 (Purple, 128 GB)',
#  'APPLE iPhone 14 (Blue, 128 GB)',
#  'APPLE iPhone 14 Plus (Starlight, 256 GB)',
#  'APPLE iPhone 14 (Blue, 256 GB)',
#  'APPLE iPhone 14 (Starlight, 128 GB)',
#  'APPLE iPhone 14 Plus (Starlight, 128 GB)',
#  'APPLE iPhone 14 Plus (Purple, 128 GB)',
#  'APPLE iPhone 14 (Starlight, 256 GB)',
#  'APPLE iPhone 14 (Purple, 256 GB)',
#  'APPLE iPhone 14 ((PRODUCT)RED, 128 GB)',
#  'APPLE iPhone 14 Plus (Midnight, 256 GB)',
#  'APPLE iPhone 14 (Midnight, 256 GB)',
#  'APPLE iPhone 14 Plus (Midnight, 128 GB)',
#  'APPLE iPhone 14 Plus (Blue, 128 GB)',
#  'APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)',
#  'APPLE iPhone 14 Plus (Blue, 256 GB)',
#  'APPLE iPhone 14 Pro (Space Black, 512 GB)',
#  'APPLE iPhone 14 Plus (Purple, 256 GB)',
#  'APPLE iPhone 14 ((PRODUCT)RED, 256 GB)',
#  'APPLE iPhone 14 Plus ((PRODUCT)RED, 256 GB)',
#  'APPLE iPhone 14 (Midnight, 512 GB)',
# ...

# %%
product_review = soup.find_all('div', class_ = '_3LWZlK')
product_review = product_review[:24]

# %%
product_review = [i.get_text() for i in product_review ]
product_review
# Out:
# ['4.6',
#  '4.6',
#  '4.6',
#  '4.5',
#  '4.6',
#  '4.6',
#  '4.5',
#  '4.5',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.5',
#  '4.6',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.7',
#  '4.5',
#  '4.6',
#  '4.5',
#  '4.6',
#  '4.7',
#  '4.7']

# %%
product_desc = soup.find_all('div', class_ = 'fMghEO')
product_desc
# Out:
# [<div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">128 GB ROM</li><li class="rgWa7D">15.49 cm (6.1 inch) Super Retina XDR Display</li><li class="rgWa7D">12MP + 12MP | 12MP Front Camera</li><li class="rgWa7D">A15 Bionic Chip, 6 Core Processor Processor</li><li class="rgWa7D">1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories</li></ul></div>,
#  <div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">128 GB ROM</li><li class="rgWa7D">15.49 cm (6.1 inch) Super Retina XDR Display</li><li class="rgWa7D">12MP + 12MP | 12MP Front Camera</li><li class="rgWa7D">A15 Bionic Chip, 6 Core Processor Processor</li><li class="rgWa7D">1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories</li></ul></div>,
# ...

# %%
product_desc = [i.get_text() for i in product_desc]
product_desc
# Out:
# ['128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip, 6 Core Processor Processor1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories',
#  '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip, 6 Core Processor Processor1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories',
#  '128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip, 6 Core Processor Processor1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories',
#  '256 GB ROM17.02 cm (6.7 inch) Super Retina XDR Display12MP + 12MP | 12MP Front CameraA15 Bionic Chip, 6 Core Processor Processor1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories',
# ...

# %%
for i in [product_price, product_price, product_name,product_review]:
    print(len(i))
# Out:
# 24
# 24
# 24
# 24

# %%
import pandas as pd
df = pd.DataFrame({
    'product_name':product_name,
    'product_price':product_price,
    'product_review':product_review,
    'product_desc':product_desc
    })

# %%
df.head(2)
# Out:
#                          product_name product_price product_review  \
# 0  APPLE iPhone 14 (Midnight, 128 GB)       ₹78,740            4.6
# 1    APPLE iPhone 14 (Purple, 128 GB)       ₹78,740            4.6
#
#                                         product_desc
# 0  128 GB ROM15.49 cm (6.1 inch) Super Retina XDR...
# 1  128 GB ROM15.49 cm (6.1 inch) Super Retina XDR...

# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome('C:\\Users\\User\\Downloads\\chromedriver_win32\\chromedriver.exe')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11396\1242454072.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\\Users\\User\\Downloads\\chromedriver_win32\\chromedriver.exe')

# %%
driver.get(link)
button = driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[1]/div[2]/div[26]/div/div/nav/a[11]/span')
button.click()

# %%
driver.current_url
# Out:
# 'https://www.flipkart.com/search?q=i+phone+14&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page=2'

# %%
link = driver.current_url

# %%
page = requests.get(link)

# %%
soup = bs(page.content, 'html.parser')
# soup

# %%
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹78,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹78,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹78,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹98,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹78,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹78,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹98,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹98,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,59,900</div>,
#  <div class="_30jeq3 _1_WHN1">₹98,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹88,740</div>,
#  <div class="_30jeq3 _1_WHN1">₹98,490</div>,
# ...

# %%
price[0].get_text()
# Out:
# '₹78,740'

# %%
price = soup.find_all('div', class_ = '_30jeq3 _1_WHN1')
product_price.extend([i.get_text() for i in price])
product_price


product = soup.find_all('div', class_ = '_4rR01T')
product_name.extend([i.get_text() for i in product])
product_name

# product_review
product_rev = soup.find_all('div', class_ = '_3LWZlK')
product_rev = product_rev[:24]
product_review.extend([i.get_text() for i in product_rev])
product_review


product_de = soup.find_all('div', class_ = 'fMghEO')
product_desc.extend([i.get_text() for i in product_de])
# product_desc

# %%
import pandas as pd
df = pd.DataFrame({
    'product_name':product_name,
    'product_price':product_price,
    'product_review':product_review,
    'product_desc':product_desc
    })

# %%
df
# Out:
#                                      product_name product_price  \
# 0              APPLE iPhone 14 (Midnight, 128 GB)       ₹78,740
# 1                APPLE iPhone 14 (Purple, 128 GB)       ₹78,740
# 2                  APPLE iPhone 14 (Blue, 128 GB)       ₹78,740
# 3        APPLE iPhone 14 Plus (Starlight, 256 GB)       ₹98,490
# 4                  APPLE iPhone 14 (Blue, 256 GB)       ₹88,740
# 5             APPLE iPhone 14 (Starlight, 128 GB)       ₹78,740
# 6        APPLE iPhone 14 Plus (Starlight, 128 GB)       ₹88,490
# 7           APPLE iPhone 14 Plus (Purple, 128 GB)       ₹88,490
# 8             APPLE iPhone 14 (Starlight, 256 GB)       ₹88,740
# 9                APPLE iPhone 14 (Purple, 256 GB)       ₹88,740
# 10         APPLE iPhone 14 ((PRODUCT)RED, 128 GB)       ₹78,740
# 11        APPLE iPhone 14 Plus (Midnight, 256 GB)       ₹98,490
# 12             APPLE iPhone 14 (Midnight, 256 GB)       ₹88,740
# 13        APPLE iPhone 14 Plus (Midnight, 128 GB)       ₹88,490
# ...
